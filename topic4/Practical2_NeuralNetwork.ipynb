# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#practical_plan">Practical Overview</a></li>
#         <li><a href="#reading_data">Preparation: importing packages and loading data </a></li>
#         <li><a href="#keras_naive">Building a Feedforward Classifier Using Keras</a></li>
#         <li><a href="#keras_tuned">Your Task: Using Different Hyperparameters </a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# <h2 id="practical_plan">Practical and Data Overview</h2>
#
# - <b> Aim: </b> using Keras to Build a Simple Neural Network for Classification
#     - Keras is a powerful and easy-to-use free open source Python library for developing and evaluating deep learning models.
#     - Keras is now part of Tensorflow
#     - Keras wraps the efficient numerical computation libraries performed in Tensorflow and allows you to define and train neural network models in just a few lines of code by specifying the design of the network's layers.
#     - Keras was build by Francois Chollet. Book: https://www.manning.com/books/deep-learning-with-python-second-edition
#     - In this tutorial, you will discover how to create your first deep learning neural network model in Python using Keras.
#     - We will use the same dataset (prima indians diabetes) in this tutorial.
# - <b>Prerequisites: </b>
#
#     - You need Tensorflow to run this tutorial. You should have installed Tensorflow during a previous practical. However, if you have missed the session, please refer to Jeff Heaton's Youtube blog for instructions:
#
#         - Windows 10:
# https://www.youtube.com/watch?v=RgO8BBNGB8w&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN
#
#         - MacOS
# https://www.youtube.com/watch?v=MpUvdLD932c&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN
#
#     - Alternatively, you can use Google Colab: https://colab.research.google.com/
#
# - <b> Practical Steps: </b>
#     - Load Data.
#     - Define Keras Model.
#     - Compile Keras Model.
#     - Fit Keras Model.
#     - Evaluate Keras Model.
#     - Make Predictions
#     - Repeat the same steps with a more tuned model and examine the performance difference.

# %% [markdown]
# <h2 id="read_data">Loading the data into appropriate variables. </h2>
#
# As in the first practical, we can directly use numpy to load the dataset into two arrays: X (2D array/matrix) and y (1D array). We will need to import the loadtxt library from numpy.

# %%
from numpy import loadtxt
from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report


dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')

# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

X.shape
# Out:
# (768, 8)

# %% [markdown]
# Note, the dataset has 9 columns and the range 0:7 will select columns from 0 to 7, stopping before index 8. If this is new to you, then you can learn more about array slicing and ranges in this blog:
#
# https://machinelearningmastery.com/index-slice-reshape-numpy-arrays-machine-learning-python/

# %% [markdown]
# <h2 id="keras_naive">Building a Feed-forward Classifier with Keras</h2>
#
# - We are now ready to define our neural network model.
# - Models in Keras are defined as a sequence of layers.
#
# - We create a Sequential model (feed forward network) and add layers one at a time until we are happy with our network architecture.
# - The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the input_dim argument and setting it to 8 for the 8 input variables.
#
# - How do we know the number of layers and their types?
#
# - This is a very hard question. There are heuristics that we can use and often the best network structure is found through a process of trial and error experimentation. Generally, you need a network large enough to capture the structure of the problem.
#
# - In this example, we will use a fully-connected network structure with three layers.
#
# - Fully connected layers are defined using the Dense class. We can specify the number of neurons or nodes in the layer as the first argument, and specify the activation function using the activation argument.
#
# - We will use the rectified linear unit (Relu) activation function on the first two layers and the Sigmoid function in the output layer.
#
# - It used to be the case that Sigmoid and Tanh activation functions were preferred for all layers. These days, better performance is achieved using the ReLU activation function. We use a sigmoid on the output layer to ensure our network output is between 0 and 1 and easy to map to either a probability of class 1 or snap to a hard classification of either class with a default threshold of 0.5.
#
# - We can piece it all together by adding each layer:
#     - The model expects rows of data with 8 variables (the input_dim=8 argument)
#     - The first hidden layer has 12 nodes and uses the relu activation function.
#     - The second hidden layer has 8 nodes and uses the relu activation function.
#     - The output layer has one node and uses the sigmoid activation function.

# %% [markdown]
# ##### First, we need to import the layers from the keras library

# %%
from keras.models import Sequential  ##We are building a sequential (feed forward) model
from keras.layers import Dense       ##Dense layers (we are adding fully connected layers)

# %%
# Create the keras model and add layers one by one, indicating the number of neurons and activation function. 

model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))  ##12 = number of neurons, input_dim = number of features
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# <b>Note</b>: the most confusing thing here is that the shape of the input to the model is defined as an argument on the first hidden layer. This means that the line of code that adds the first Dense layer is doing 2 things, defining the input or visible layer and the first hidden layer.

# %% [markdown]
# ####  Compile Keras Model
# Now that the model is defined, we can compile it.
#
# Compiling the model uses the efficient numerical libraries under the covers (the so-called backend) such as Theano or TensorFlow. The backend automatically chooses the best way to represent the network for training and making predictions to run on your hardware, such as CPU or GPU or even distributed.
#
# When compiling, we must specify some additional properties required when training the network. Remember training a network means finding the best set of weights and biases to map inputs to outputs in our dataset.
#
# We must specify the loss function (i.e. the error) to use to evaluate a set of weights, the optimizer is used to search through different weights for the network and any optional metrics we would like to collect and report during training.
#
# In this case, we will use cross entropy as the loss argument. This loss is for a binary classification problems and is defined in Keras as <b>binary_crossentropy</b>. You can learn more about choosing loss functions based on your problem here:
#
# https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm <b>adam</b>. This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems. To learn more about the Adam version of stochastic gradient descent see the post:
#
# https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
# Finally, because it is a classification problem, we will collect and report the classification accuracy, defined via the <b>metrics</b> argument.
#
# The file code to compile network becomes:

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# - A good explanation of the difference between the loss and metrics arguments:
#
# https://stackoverflow.com/questions/48280873/what-is-the-difference-between-loss-function-and-metric-in-keras#:~:text=The%20loss%20function%20is%20used,do%20with%20the%20optimization%20process.

# %% [markdown]
# #### Fit Keras Model
# We have defined our model and compiled it ready for efficient computation.
#
# Now it is time to execute the model on some data.
#
# We can train or fit our model on our loaded data by calling the fit() function on the model.
#
# Training occurs over epochs and each epoch is split into batches.
#
# - Epoch: One pass through all of the rows in the training dataset.
# - Batch: One or more samples considered by the model within an epoch before weights are updated.
#
# One epoch is comprised of one or more batches, based on the chosen batch size and the model is fit for many epochs. For more on the difference between epochs and batches, see the link:
#
# https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/

# %% [markdown]
# The training process will run for a fixed number of iterations through the dataset called epochs, that we must specify using the <b>epochs</b> argument. We must also set the number of dataset rows that are considered before the model weights are updated within each epoch, called the batch size and set using the <b>batch_size</b> argument.
#
# For this problem, we will run for a small number of epochs (150) and use a relatively small batch size of 10.
#
# These configurations can be chosen experimentally by trial and error. We want to train the model enough so that it learns a good (or good enough) mapping of rows of input data to the output classification. The model will always have some error, but the amount of error will level out after some point for a given model configuration. This is called model convergence.

# %%
# fit the keras model on the dataset
model.fit(x_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 70/70 [==============================] - 0s 558us/step - loss: 3.7395 - accuracy: 0.3564
# Epoch 2/150
# 70/70 [==============================] - 0s 478us/step - loss: 1.1569 - accuracy: 0.5456
# Epoch 3/150
# 70/70 [==============================] - 0s 490us/step - loss: 0.7504 - accuracy: 0.6704
# Epoch 4/150
# 70/70 [==============================] - 0s 506us/step - loss: 0.7067 - accuracy: 0.5982
# Epoch 5/150
# 70/70 [==============================] - 0s 463us/step - loss: 0.6624 - accuracy: 0.7038
# Epoch 6/150
# 70/70 [==============================] - 0s 474us/step - loss: 0.6551 - accuracy: 0.6733
# Epoch 7/150
# 70/70 [==============================] - 0s 477us/step - loss: 0.6513 - accuracy: 0.6663
# Epoch 8/150
# 70/70 [==============================] - 0s 472us/step - loss: 0.6397 - accuracy: 0.6651
# Epoch 9/150
# 70/70 [==============================] - 0s 470us/step - loss: 0.6442 - accuracy: 0.6472
# Epoch 10/150
# 70/70 [==============================] - 0s 489us/step - loss: 0.6283 - accuracy: 0.6852
# Epoch 11/150
# 70/70 [==============================] - 0s 490us/step - loss: 0.6221 - accuracy: 0.6779
# Epoch 12/150
# 70/70 [==============================] - 0s 471us/step - loss: 0.6115 - accuracy: 0.6784
# Epoch 13/150
# 70/70 [==============================] - 0s 474us/step - loss: 0.6258 - accuracy: 0.6780
# Epoch 14/150
# 70/70 [==============================] - 0s 475us/step - loss: 0.6279 - accuracy: 0.6457
# Epoch 15/150
# 70/70 [==============================] - 0s 478us/step - loss: 0.6078 - accuracy: 0.6783
# Epoch 16/150
# 70/70 [==============================] - 0s 482us/step - loss: 0.6097 - accuracy: 0.6789
# Epoch 17/150
# 70/70 [==============================] - 0s 490us/step - loss: 0.6217 - accuracy: 0.6588
# Epoch 18/150
# 70/70 [==============================] - 0s 485us/step - loss: 0.6216 - accuracy: 0.6532
# Epoch 19/150
# 70/70 [==============================] - 0s 623us/step - loss: 0.6202 - accuracy: 0.6642
# Epoch 20/150
# 70/70 [==============================] - 0s 476us/step - loss: 0.5953 - accuracy: 0.6825
# Epoch 21/150
# 70/70 [==============================] - 0s 496us/step - loss: 0.5926 - accuracy: 0.6800
# Epoch 22/150
# 70/70 [==============================] - 0s 467us/step - loss: 0.5869 - accuracy: 0.6972
# Epoch 23/150
# 70/70 [==============================] - 0s 461us/step - loss: 0.5969 - accuracy: 0.6789
# Epoch 24/150
# 70/70 [==============================] - 0s 452us/step - loss: 0.6078 - accuracy: 0.6524
# Epoch 25/150
# 70/70 [==============================] - 0s 475us/step - loss: 0.6017 - accuracy: 0.6895
# Epoch 26/150
# 70/70 [==============================] - 0s 467us/step - loss: 0.5854 - accuracy: 0.7099
# Epoch 27/150
# 70/70 [==============================] - 0s 457us/step - loss: 0.5767 - accuracy: 0.6837
# Epoch 28/150
# 70/70 [==============================] - 0s 456us/step - loss: 0.5821 - accuracy: 0.7057
# Epoch 29/150
# 70/70 [==============================] - 0s 479us/step - loss: 0.5602 - accuracy: 0.7274
# Epoch 30/150
# 70/70 [==============================] - 0s 463us/step - loss: 0.5859 - accuracy: 0.7043
# Epoch 31/150
# 70/70 [==============================] - 0s 439us/step - loss: 0.5761 - accuracy: 0.6998
# Epoch 32/150
# 70/70 [==============================] - 0s 462us/step - loss: 0.5768 - accuracy: 0.6819
# Epoch 33/150
# 70/70 [==============================] - 0s 515us/step - loss: 0.5538 - accuracy: 0.7012
# Epoch 34/150
# 70/70 [==============================] - 0s 474us/step - loss: 0.5680 - accuracy: 0.6870
# Epoch 35/150
# 70/70 [==============================] - 0s 466us/step - loss: 0.5654 - accuracy: 0.7083
# Epoch 36/150
# 70/70 [==============================] - 0s 463us/step - loss: 0.5653 - accuracy: 0.7150
# Epoch 37/150
# 70/70 [==============================] - 0s 495us/step - loss: 0.5701 - accuracy: 0.7075
# Epoch 38/150
# 70/70 [==============================] - 0s 475us/step - loss: 0.5583 - accuracy: 0.7181
# Epoch 39/150
# 70/70 [==============================] - 0s 456us/step - loss: 0.5654 - accuracy: 0.7038
# Epoch 40/150
# 70/70 [==============================] - 0s 487us/step - loss: 0.5528 - accuracy: 0.6999
# Epoch 41/150
# 70/70 [==============================] - 0s 488us/step - loss: 0.5555 - accuracy: 0.7200
# Epoch 42/150
# 70/70 [==============================] - 0s 466us/step - loss: 0.5422 - accuracy: 0.7161
# Epoch 43/150
# 70/70 [==============================] - 0s 495us/step - loss: 0.5619 - accuracy: 0.6974
# Epoch 44/150
# 70/70 [==============================] - 0s 454us/step - loss: 0.5736 - accuracy: 0.6875
# Epoch 45/150
# 70/70 [==============================] - 0s 465us/step - loss: 0.5770 - accuracy: 0.6828
# Epoch 46/150
# 70/70 [==============================] - 0s 487us/step - loss: 0.5477 - accuracy: 0.7345
# Epoch 47/150
# 70/70 [==============================] - 0s 458us/step - loss: 0.5698 - accuracy: 0.6899
# Epoch 48/150
# 70/70 [==============================] - 0s 443us/step - loss: 0.5498 - accuracy: 0.7006
# Epoch 49/150
# 70/70 [==============================] - 0s 480us/step - loss: 0.5398 - accuracy: 0.7050
# Epoch 50/150
# 70/70 [==============================] - 0s 466us/step - loss: 0.5654 - accuracy: 0.6869
# Epoch 51/150
# 70/70 [==============================] - 0s 468us/step - loss: 0.5775 - accuracy: 0.7106
# Epoch 52/150
# 70/70 [==============================] - 0s 474us/step - loss: 0.5504 - accuracy: 0.6984
# Epoch 53/150
# 70/70 [==============================] - 0s 501us/step - loss: 0.5576 - accuracy: 0.7093
# Epoch 54/150
# 70/70 [==============================] - 0s 483us/step - loss: 0.5488 - accuracy: 0.7340
# Epoch 55/150
# 70/70 [==============================] - 0s 472us/step - loss: 0.5321 - accuracy: 0.7246
# Epoch 56/150
# 70/70 [==============================] - 0s 459us/step - loss: 0.5795 - accuracy: 0.6889
# Epoch 57/150
# 70/70 [==============================] - 0s 471us/step - loss: 0.5642 - accuracy: 0.7079
# Epoch 58/150
# 70/70 [==============================] - 0s 484us/step - loss: 0.5618 - accuracy: 0.6978
# Epoch 59/150
# 70/70 [==============================] - 0s 520us/step - loss: 0.5355 - accuracy: 0.7032
# Epoch 60/150
# 70/70 [==============================] - 0s 468us/step - loss: 0.5482 - accuracy: 0.7135
# Epoch 61/150
# 70/70 [==============================] - 0s 468us/step - loss: 0.5652 - accuracy: 0.7248
# Epoch 62/150
# 70/70 [==============================] - 0s 480us/step - loss: 0.5559 - accuracy: 0.7212
# Epoch 63/150
# 70/70 [==============================] - 0s 491us/step - loss: 0.5517 - accuracy: 0.7083
# Epoch 64/150
# 70/70 [==============================] - 0s 449us/step - loss: 0.5436 - accuracy: 0.7248
# Epoch 65/150
# 70/70 [==============================] - 0s 481us/step - loss: 0.5426 - accuracy: 0.7076
# Epoch 66/150
# 70/70 [==============================] - 0s 493us/step - loss: 0.5371 - accuracy: 0.7279
# Epoch 67/150
# 70/70 [==============================] - 0s 474us/step - loss: 0.5469 - accuracy: 0.7018
# Epoch 68/150
# 70/70 [==============================] - 0s 463us/step - loss: 0.5301 - accuracy: 0.6971
# Epoch 69/150
# 70/70 [==============================] - 0s 497us/step - loss: 0.5387 - accuracy: 0.7159
# Epoch 70/150
# 70/70 [==============================] - 0s 499us/step - loss: 0.5474 - accuracy: 0.7248
# Epoch 71/150
# 70/70 [==============================] - 0s 477us/step - loss: 0.5432 - accuracy: 0.7147
# Epoch 72/150
# 70/70 [==============================] - 0s 473us/step - loss: 0.5198 - accuracy: 0.7318
# Epoch 73/150
# 70/70 [==============================] - 0s 451us/step - loss: 0.5269 - accuracy: 0.7213
# Epoch 74/150
# 70/70 [==============================] - 0s 479us/step - loss: 0.5329 - accuracy: 0.7114
# Epoch 75/150
# 70/70 [==============================] - 0s 448us/step - loss: 0.5399 - accuracy: 0.7114
# Epoch 76/150
# 70/70 [==============================] - 0s 478us/step - loss: 0.5602 - accuracy: 0.7277
# Epoch 77/150
# 70/70 [==============================] - 0s 461us/step - loss: 0.5406 - accuracy: 0.7084
# Epoch 78/150
# 70/70 [==============================] - 0s 483us/step - loss: 0.5352 - accuracy: 0.7323
# Epoch 79/150
# 70/70 [==============================] - 0s 490us/step - loss: 0.5344 - accuracy: 0.7183
# Epoch 80/150
# 70/70 [==============================] - 0s 474us/step - loss: 0.5321 - accuracy: 0.7164
# Epoch 81/150
# 70/70 [==============================] - 0s 478us/step - loss: 0.5333 - accuracy: 0.7073
# Epoch 82/150
# 70/70 [==============================] - 0s 460us/step - loss: 0.5065 - accuracy: 0.7478
# Epoch 83/150
# 70/70 [==============================] - 0s 456us/step - loss: 0.5455 - accuracy: 0.7601
# Epoch 84/150
# 70/70 [==============================] - 0s 451us/step - loss: 0.5153 - accuracy: 0.7243
# Epoch 85/150
# 70/70 [==============================] - 0s 455us/step - loss: 0.5148 - accuracy: 0.7551
# Epoch 86/150
# 70/70 [==============================] - 0s 447us/step - loss: 0.5191 - accuracy: 0.7335
# Epoch 87/150
# 70/70 [==============================] - 0s 450us/step - loss: 0.5356 - accuracy: 0.7255
# Epoch 88/150
# 70/70 [==============================] - 0s 450us/step - loss: 0.5414 - accuracy: 0.7041
# Epoch 89/150
# 70/70 [==============================] - 0s 780us/step - loss: 0.5411 - accuracy: 0.7168
# Epoch 90/150
# 70/70 [==============================] - 0s 517us/step - loss: 0.5257 - accuracy: 0.7192
# Epoch 91/150
# 70/70 [==============================] - 0s 470us/step - loss: 0.5206 - accuracy: 0.7102
# Epoch 92/150
# 70/70 [==============================] - 0s 452us/step - loss: 0.5351 - accuracy: 0.7183
# Epoch 93/150
# 70/70 [==============================] - 0s 474us/step - loss: 0.5249 - accuracy: 0.7356
# Epoch 94/150
# 70/70 [==============================] - 0s 485us/step - loss: 0.5251 - accuracy: 0.7232
# Epoch 95/150
# 70/70 [==============================] - 0s 494us/step - loss: 0.5357 - accuracy: 0.7340
# Epoch 96/150
# 70/70 [==============================] - 0s 485us/step - loss: 0.5586 - accuracy: 0.6990
# Epoch 97/150
# 70/70 [==============================] - 0s 452us/step - loss: 0.5008 - accuracy: 0.7358
# Epoch 98/150
# 70/70 [==============================] - 0s 449us/step - loss: 0.5277 - accuracy: 0.6951
# Epoch 99/150
# 70/70 [==============================] - 0s 469us/step - loss: 0.5167 - accuracy: 0.7238
# Epoch 100/150
# 70/70 [==============================] - 0s 448us/step - loss: 0.5184 - accuracy: 0.7369
# Epoch 101/150
# 70/70 [==============================] - 0s 449us/step - loss: 0.5033 - accuracy: 0.7409
# Epoch 102/150
# 70/70 [==============================] - 0s 451us/step - loss: 0.5271 - accuracy: 0.7296
# Epoch 103/150
# 70/70 [==============================] - 0s 448us/step - loss: 0.4882 - accuracy: 0.7408
# Epoch 104/150
# 70/70 [==============================] - 0s 450us/step - loss: 0.5456 - accuracy: 0.7064
# Epoch 105/150
# 70/70 [==============================] - 0s 449us/step - loss: 0.5241 - accuracy: 0.7188
# Epoch 106/150
# 70/70 [==============================] - 0s 446us/step - loss: 0.5391 - accuracy: 0.7290
# Epoch 107/150
# 70/70 [==============================] - 0s 449us/step - loss: 0.5307 - accuracy: 0.7195
# Epoch 108/150
# 70/70 [==============================] - 0s 444us/step - loss: 0.5284 - accuracy: 0.7208
# Epoch 109/150
# 70/70 [==============================] - 0s 479us/step - loss: 0.5267 - accuracy: 0.7184
# Epoch 110/150
# 70/70 [==============================] - 0s 446us/step - loss: 0.5500 - accuracy: 0.6887
# Epoch 111/150
# 70/70 [==============================] - 0s 459us/step - loss: 0.5267 - accuracy: 0.6940
# Epoch 112/150
# 70/70 [==============================] - 0s 715us/step - loss: 0.4848 - accuracy: 0.7504
# Epoch 113/150
# 70/70 [==============================] - 0s 454us/step - loss: 0.5218 - accuracy: 0.7219
# Epoch 114/150
# 70/70 [==============================] - 0s 462us/step - loss: 0.5107 - accuracy: 0.7158
# Epoch 115/150
# 70/70 [==============================] - 0s 461us/step - loss: 0.5285 - accuracy: 0.7384
# Epoch 116/150
# 70/70 [==============================] - 0s 461us/step - loss: 0.4912 - accuracy: 0.7443
# Epoch 117/150
# 70/70 [==============================] - 0s 483us/step - loss: 0.5008 - accuracy: 0.7298
# Epoch 118/150
# 70/70 [==============================] - 0s 467us/step - loss: 0.5270 - accuracy: 0.7215
# Epoch 119/150
# 70/70 [==============================] - 0s 458us/step - loss: 0.5315 - accuracy: 0.7143
# Epoch 120/150
# 70/70 [==============================] - 0s 475us/step - loss: 0.4804 - accuracy: 0.7671
# Epoch 121/150
# 70/70 [==============================] - 0s 477us/step - loss: 0.5174 - accuracy: 0.7109
# Epoch 122/150
# 70/70 [==============================] - 0s 454us/step - loss: 0.5093 - accuracy: 0.7428
# Epoch 123/150
# 70/70 [==============================] - 0s 447us/step - loss: 0.5117 - accuracy: 0.7352
# Epoch 124/150
# 70/70 [==============================] - 0s 464us/step - loss: 0.5299 - accuracy: 0.7152
# Epoch 125/150
# 70/70 [==============================] - 0s 452us/step - loss: 0.5216 - accuracy: 0.7288
# Epoch 126/150
# 70/70 [==============================] - 0s 451us/step - loss: 0.4946 - accuracy: 0.7218
# Epoch 127/150
# 70/70 [==============================] - 0s 446us/step - loss: 0.5117 - accuracy: 0.7318
# Epoch 128/150
# 70/70 [==============================] - 0s 458us/step - loss: 0.5110 - accuracy: 0.7412
# Epoch 129/150
# 70/70 [==============================] - 0s 477us/step - loss: 0.4861 - accuracy: 0.7522
# Epoch 130/150
# 70/70 [==============================] - 0s 466us/step - loss: 0.5218 - accuracy: 0.7342
# Epoch 131/150
# 70/70 [==============================] - 0s 452us/step - loss: 0.5400 - accuracy: 0.6956
# Epoch 132/150
# 70/70 [==============================] - 0s 455us/step - loss: 0.4945 - accuracy: 0.7337
# Epoch 133/150
# 70/70 [==============================] - 0s 459us/step - loss: 0.5323 - accuracy: 0.7025
# Epoch 134/150
# 70/70 [==============================] - 0s 463us/step - loss: 0.4911 - accuracy: 0.7460
# Epoch 135/150
# 70/70 [==============================] - 0s 454us/step - loss: 0.5193 - accuracy: 0.7188
# Epoch 136/150
# 70/70 [==============================] - 0s 454us/step - loss: 0.4559 - accuracy: 0.7886
# Epoch 137/150
# 70/70 [==============================] - 0s 447us/step - loss: 0.5093 - accuracy: 0.7284
# Epoch 138/150
# 70/70 [==============================] - 0s 454us/step - loss: 0.5014 - accuracy: 0.7315
# Epoch 139/150
# 70/70 [==============================] - 0s 453us/step - loss: 0.5053 - accuracy: 0.7287
# Epoch 140/150
# 70/70 [==============================] - 0s 447us/step - loss: 0.4944 - accuracy: 0.7439
# Epoch 141/150
# 70/70 [==============================] - 0s 446us/step - loss: 0.5131 - accuracy: 0.7326
# Epoch 142/150
# 70/70 [==============================] - 0s 446us/step - loss: 0.4977 - accuracy: 0.7387
# Epoch 143/150
# 70/70 [==============================] - 0s 451us/step - loss: 0.5188 - accuracy: 0.7118
# Epoch 144/150
# 70/70 [==============================] - 0s 454us/step - loss: 0.5245 - accuracy: 0.7297
# Epoch 145/150
# 70/70 [==============================] - 0s 446us/step - loss: 0.4906 - accuracy: 0.7445
# Epoch 146/150
# 70/70 [==============================] - 0s 446us/step - loss: 0.5159 - accuracy: 0.7367
# Epoch 147/150
# 70/70 [==============================] - 0s 460us/step - loss: 0.4986 - accuracy: 0.7272
# Epoch 148/150
# 70/70 [==============================] - 0s 460us/step - loss: 0.5003 - accuracy: 0.7224
# Epoch 149/150
# 70/70 [==============================] - 0s 452us/step - loss: 0.5488 - accuracy: 0.7061
# Epoch 150/150
# 70/70 [==============================] - 0s 455us/step - loss: 0.4769 - accuracy: 0.7525

# %% [markdown]
# ####  Evaluate Keras Model
# We have trained our neural network on the training dataset and we can evaluate the performance of the network on the test dataset. Let's first use the model to predict the actual classes for the test set
#
# Making predictions is as easy as calling the predict() function on the model. We are using a sigmoid activation function on the output layer, so the predictions will be a probability in the range between 0 and 1. We can easily convert them into a crisp binary prediction for this classification task by rounding them.
#
# ou can visualise your predictions using any of the sklearn capabilities. Example below shows the classification report.
#
# For example:

# %%
# make probability predictions with the model
predictions = model.predict(x_test)
# round predictions 
rounded = [round(x[0]) for x in predictions]
print(classification_report(y_test, rounded))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.84      0.71        44
#          1.0       0.59      0.30      0.40        33
#
#     accuracy                           0.61        77
#    macro avg       0.60      0.57      0.56        77
# weighted avg       0.60      0.61      0.58        77

# %% [markdown]
# <h2 id="keras_tuned">Changing the Model's Hyperparameters</h2>
#
#  - The NN above shows a very bad performance with respect to the positive class.
#  - Can we do better? let's try differnt parameters:
#      - batch_size
#      - epochs
#      - metrics (try: metrics=tf.keras.metrics.Precision())

# %%
### Your solution here ###

# %%
## the model still performs badly, especially w.r.t. the positive class. There's a big class imbalance, see here: 
import numpy as np

values, counts = np.unique(y, return_counts=True)
print(counts)
##there is double the number of samples in the negative class. 
## NNs are very data hungry. they would require much more data about the positive class to make good predictions!
## We will learn how to deal with class imbalance next week! :)
# Out:
# [500 268]
