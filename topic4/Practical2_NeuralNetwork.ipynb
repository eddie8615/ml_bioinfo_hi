# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#practical_plan">Practical Overview</a></li>
#         <li><a href="#reading_data">Preparation: importing packages and loading data </a></li>
#         <li><a href="#keras_naive">Building a Feedforward Classifier Using Keras</a></li>
#         <li><a href="#keras_tuned">Your Task: Using Different Hyperparameters </a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# <h2 id="practical_plan">Practical and Data Overview</h2>
#
# - <b> Aim: </b> using Keras to Build a Simple Neural Network for Classification
#     - Keras is a powerful and easy-to-use free open source Python library for developing and evaluating deep learning models.
#     - Keras is now part of Tensorflow
#     - Keras wraps the efficient numerical computation libraries performed in Tensorflow and allows you to define and train neural network models in just a few lines of code by specifying the design of the network's layers.
#     - Keras was build by Francois Chollet. Book: https://www.manning.com/books/deep-learning-with-python-second-edition
#     - In this tutorial, you will discover how to create your first deep learning neural network model in Python using Keras.
#     - We will use the same dataset (prima indians diabetes) in this tutorial.
# - <b>Prerequisites: </b>
#
#     - You need Tensorflow to run this tutorial. You should have installed Tensorflow during a previous practical. However, if you have missed the session, please refer to Jeff Heaton's Youtube blog for instructions:
#
#         - Windows 10:
# https://www.youtube.com/watch?v=RgO8BBNGB8w&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN
#
#         - MacOS
# https://www.youtube.com/watch?v=MpUvdLD932c&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN
#
#     - Alternatively, you can use Google Colab: https://colab.research.google.com/
#
# - <b> Practical Steps: </b>
#     - Load Data.
#     - Define Keras Model.
#     - Compile Keras Model.
#     - Fit Keras Model.
#     - Evaluate Keras Model.
#     - Make Predictions
#     - Repeat the same steps with a more tuned model and examine the performance difference.

# %% [markdown]
# <h2 id="read_data">Loading the data into appropriate variables. </h2>
#
# As in the first practical, we can directly use numpy to load the dataset into two arrays: X (2D array/matrix) and y (1D array). We will need to import the loadtxt library from numpy.

# %%
from numpy import loadtxt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report


dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')

# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

X.shape
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       2 from sklearn.model_selection import train_test_split, GridSearchCV
#       3 from sklearn.metrics import classification_report
# ----> 4 from keras.optimizers import Adam
#       7 dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
#       9 # split into input (X) and output (y) variables
#
# ImportError: cannot import name 'Adam' from 'keras.optimizers' (/home/changhyun/King's College London/ml_bioinfo_hi/mlBioHealth/lib/python3.8/site-packages/keras/optimizers.py)

# %% [markdown]
# Note, the dataset has 9 columns and the range 0:7 will select columns from 0 to 7, stopping before index 8. If this is new to you, then you can learn more about array slicing and ranges in this blog:
#
# https://machinelearningmastery.com/index-slice-reshape-numpy-arrays-machine-learning-python/

# %% [markdown]
# <h2 id="keras_naive">Building a Feed-forward Classifier with Keras</h2>
#
# - We are now ready to define our neural network model.
# - Models in Keras are defined as a sequence of layers.
#
# - We create a Sequential model (feed forward network) and add layers one at a time until we are happy with our network architecture.
# - The first thing to get right is to ensure the input layer has the right number of input features. This can be specified when creating the first layer with the input_dim argument and setting it to 8 for the 8 input variables.
#
# - How do we know the number of layers and their types?
#
# - This is a very hard question. There are heuristics that we can use and often the best network structure is found through a process of trial and error experimentation. Generally, you need a network large enough to capture the structure of the problem.
#
# - In this example, we will use a fully-connected network structure with three layers.
#
# - Fully connected layers are defined using the Dense class. We can specify the number of neurons or nodes in the layer as the first argument, and specify the activation function using the activation argument.
#
# - We will use the rectified linear unit (Relu) activation function on the first two layers and the Sigmoid function in the output layer.
#
# - It used to be the case that Sigmoid and Tanh activation functions were preferred for all layers. These days, better performance is achieved using the ReLU activation function. We use a sigmoid on the output layer to ensure our network output is between 0 and 1 and easy to map to either a probability of class 1 or snap to a hard classification of either class with a default threshold of 0.5.
#
# - We can piece it all together by adding each layer:
#     - The model expects rows of data with 8 variables (the input_dim=8 argument)
#     - The first hidden layer has 12 nodes and uses the relu activation function.
#     - The second hidden layer has 8 nodes and uses the relu activation function.
#     - The output layer has one node and uses the sigmoid activation function.

# %% [markdown]
# ##### First, we need to import the layers from the keras library

# %%
from keras.models import Sequential  ##We are building a sequential (feed forward) model
from keras.layers import Dense  
from keras.wrappers.scikit_learn import KerasClassifier##Dense layers (we are adding fully connected layers)

# %%
# Create the keras model and add layers one by one, indicating the number of neurons and activation function. 

model = Sequential()
model.add(Dense(20, input_dim=8, activation='relu'))  ##12 = number of neurons, input_dim = number of features
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# <b>Note</b>: the most confusing thing here is that the shape of the input to the model is defined as an argument on the first hidden layer. This means that the line of code that adds the first Dense layer is doing 2 things, defining the input or visible layer and the first hidden layer.

# %% [markdown]
# ####  Compile Keras Model
# Now that the model is defined, we can compile it.
#
# Compiling the model uses the efficient numerical libraries under the covers (the so-called backend) such as Theano or TensorFlow. The backend automatically chooses the best way to represent the network for training and making predictions to run on your hardware, such as CPU or GPU or even distributed.
#
# When compiling, we must specify some additional properties required when training the network. Remember training a network means finding the best set of weights and biases to map inputs to outputs in our dataset.
#
# We must specify the loss function (i.e. the error) to use to evaluate a set of weights, the optimizer is used to search through different weights for the network and any optional metrics we would like to collect and report during training.
#
# In this case, we will use cross entropy as the loss argument. This loss is for a binary classification problems and is defined in Keras as <b>binary_crossentropy</b>. You can learn more about choosing loss functions based on your problem here:
#
# https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm <b>adam</b>. This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems. To learn more about the Adam version of stochastic gradient descent see the post:
#
# https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/
# Finally, because it is a classification problem, we will collect and report the classification accuracy, defined via the <b>metrics</b> argument.
#
# The file code to compile network becomes:

# %%
# compile the keras model
import tensorflow as tf
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.keras.metrics.Precision()])

# %% [markdown]
# - A good explanation of the difference between the loss and metrics arguments:
#
# https://stackoverflow.com/questions/48280873/what-is-the-difference-between-loss-function-and-metric-in-keras#:~:text=The%20loss%20function%20is%20used,do%20with%20the%20optimization%20process.

# %% [markdown]
# #### Fit Keras Model
# We have defined our model and compiled it ready for efficient computation.
#
# Now it is time to execute the model on some data.
#
# We can train or fit our model on our loaded data by calling the fit() function on the model.
#
# Training occurs over epochs and each epoch is split into batches.
#
# - Epoch: One pass through all of the rows in the training dataset.
# - Batch: One or more samples considered by the model within an epoch before weights are updated.
#
# One epoch is comprised of one or more batches, based on the chosen batch size and the model is fit for many epochs. For more on the difference between epochs and batches, see the link:
#
# https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/

# %% [markdown]
# The training process will run for a fixed number of iterations through the dataset called epochs, that we must specify using the <b>epochs</b> argument. We must also set the number of dataset rows that are considered before the model weights are updated within each epoch, called the batch size and set using the <b>batch_size</b> argument.
#
# For this problem, we will run for a small number of epochs (150) and use a relatively small batch size of 10.
#
# These configurations can be chosen experimentally by trial and error. We want to train the model enough so that it learns a good (or good enough) mapping of rows of input data to the output classification. The model will always have some error, but the amount of error will level out after some point for a given model configuration. This is called model convergence.

# %%
# fit the keras model on the dataset
model.fit(x_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9842 - accuracy: 0.4834
# Epoch 2/150
# 70/70 [==============================] - 0s 1ms/step - loss: 1.1465 - accuracy: 0.5412
# Epoch 3/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.9034 - accuracy: 0.5832
# Epoch 4/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.8401 - accuracy: 0.5876
# Epoch 5/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.7807 - accuracy: 0.6006
# Epoch 6/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.7356 - accuracy: 0.6266
# Epoch 7/150
# 70/70 [==============================] - 0s 2ms/step - loss: 0.7250 - accuracy: 0.6527
# Epoch 8/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.7071 - accuracy: 0.6397
# Epoch 9/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6814 - accuracy: 0.6628
# Epoch 10/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6648 - accuracy: 0.6628
# Epoch 11/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6687 - accuracy: 0.6599
# Epoch 12/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6358 - accuracy: 0.6744
# Epoch 13/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6598 - accuracy: 0.6686
# Epoch 14/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6183 - accuracy: 0.6874
# Epoch 15/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6262 - accuracy: 0.6671
# Epoch 16/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.6787
# Epoch 17/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6041 - accuracy: 0.6975
# Epoch 18/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5910 - accuracy: 0.7062
# Epoch 19/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5897 - accuracy: 0.7004
# Epoch 20/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.6038 - accuracy: 0.7033
# Epoch 21/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7352
# Epoch 22/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5907 - accuracy: 0.7106
# Epoch 23/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5824 - accuracy: 0.7120
# Epoch 24/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5898 - accuracy: 0.6961
# Epoch 25/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5967 - accuracy: 0.7207
# Epoch 26/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5726 - accuracy: 0.7221
# Epoch 27/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5704 - accuracy: 0.7236
# Epoch 28/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5533 - accuracy: 0.7294
# Epoch 29/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5753 - accuracy: 0.7308
# Epoch 30/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5665 - accuracy: 0.7323
# Epoch 31/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5821 - accuracy: 0.7149
# Epoch 32/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5776 - accuracy: 0.7178
# Epoch 33/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5464 - accuracy: 0.7410
# Epoch 34/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5491 - accuracy: 0.7337
# Epoch 35/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5578 - accuracy: 0.7250
# Epoch 36/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5426 - accuracy: 0.7352
# Epoch 37/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5455 - accuracy: 0.7323
# Epoch 38/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5451 - accuracy: 0.7279
# Epoch 39/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5634 - accuracy: 0.7438
# Epoch 40/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5459 - accuracy: 0.7366
# Epoch 41/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5569 - accuracy: 0.7279
# Epoch 42/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5899 - accuracy: 0.7033
# Epoch 43/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5431 - accuracy: 0.7482
# Epoch 44/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5275 - accuracy: 0.7438
# Epoch 45/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5377 - accuracy: 0.7410
# Epoch 46/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5736 - accuracy: 0.7033
# Epoch 47/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5375 - accuracy: 0.7395
# Epoch 48/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5363 - accuracy: 0.7424
# Epoch 49/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5407 - accuracy: 0.7323
# Epoch 50/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5331 - accuracy: 0.7395
# Epoch 51/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7424
# Epoch 52/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5348 - accuracy: 0.7337
# Epoch 53/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5558 - accuracy: 0.7178
# Epoch 54/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5414 - accuracy: 0.7250
# Epoch 55/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5361 - accuracy: 0.7424
# Epoch 56/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5300 - accuracy: 0.7453
# Epoch 57/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5457 - accuracy: 0.7410
# Epoch 58/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5608 - accuracy: 0.7019
# Epoch 59/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5237 - accuracy: 0.7424
# Epoch 60/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5139 - accuracy: 0.7438
# Epoch 61/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5142 - accuracy: 0.7598
# Epoch 62/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5328 - accuracy: 0.7294
# Epoch 63/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5205 - accuracy: 0.7438
# Epoch 64/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5372 - accuracy: 0.7221
# Epoch 65/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5333 - accuracy: 0.7366
# Epoch 66/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5131 - accuracy: 0.7453
# Epoch 67/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5264 - accuracy: 0.7279
# Epoch 68/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5266 - accuracy: 0.7337
# Epoch 69/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5143 - accuracy: 0.7366
# Epoch 70/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5365 - accuracy: 0.7279
# Epoch 71/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5139 - accuracy: 0.7554
# Epoch 72/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5126 - accuracy: 0.7438
# Epoch 73/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5099 - accuracy: 0.7569
# Epoch 74/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5329 - accuracy: 0.7323
# Epoch 75/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5453 - accuracy: 0.7279
# Epoch 76/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5160 - accuracy: 0.7467
# Epoch 77/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5136 - accuracy: 0.7467
# Epoch 78/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4970 - accuracy: 0.7612
# Epoch 79/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5022 - accuracy: 0.7641
# Epoch 80/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4937 - accuracy: 0.7554
# Epoch 81/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5062 - accuracy: 0.7540
# Epoch 82/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5174 - accuracy: 0.7511
# Epoch 83/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5068 - accuracy: 0.7641
# Epoch 84/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5240 - accuracy: 0.7410
# Epoch 85/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5840 - accuracy: 0.7077
# Epoch 86/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5249 - accuracy: 0.7467
# Epoch 87/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5249 - accuracy: 0.7410
# Epoch 88/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5055 - accuracy: 0.7583
# Epoch 89/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4948 - accuracy: 0.7467
# Epoch 90/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5158 - accuracy: 0.7482
# Epoch 91/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5007 - accuracy: 0.7467
# Epoch 92/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5028 - accuracy: 0.7482
# Epoch 93/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4969 - accuracy: 0.7554
# Epoch 94/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5109 - accuracy: 0.7496
# Epoch 95/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4966 - accuracy: 0.7453
# Epoch 96/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4978 - accuracy: 0.7612
# Epoch 97/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5171 - accuracy: 0.7569
# Epoch 98/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4986 - accuracy: 0.7496
# Epoch 99/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5284 - accuracy: 0.7453
# Epoch 100/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4991 - accuracy: 0.7583
# Epoch 101/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4870 - accuracy: 0.7554
# Epoch 102/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4895 - accuracy: 0.7685
# Epoch 103/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4959 - accuracy: 0.7540
# Epoch 104/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4982 - accuracy: 0.7554
# Epoch 105/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4955 - accuracy: 0.7670
# Epoch 106/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4874 - accuracy: 0.7627
# Epoch 107/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4978 - accuracy: 0.7583
# Epoch 108/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4922 - accuracy: 0.7598
# Epoch 109/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4994 - accuracy: 0.7728
# Epoch 110/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5013 - accuracy: 0.7612
# Epoch 111/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5258 - accuracy: 0.7453
# Epoch 112/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5016 - accuracy: 0.7656
# Epoch 113/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5326 - accuracy: 0.7569
# Epoch 114/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4972 - accuracy: 0.7540
# Epoch 115/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4946 - accuracy: 0.7453
# Epoch 116/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4958 - accuracy: 0.7815
# Epoch 117/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4770 - accuracy: 0.7670
# Epoch 118/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5107 - accuracy: 0.7395
# Epoch 119/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.7438
# Epoch 120/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4978 - accuracy: 0.7641
# Epoch 121/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4962 - accuracy: 0.7583
# Epoch 122/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4840 - accuracy: 0.7757
# Epoch 123/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4939 - accuracy: 0.7612
# Epoch 124/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4872 - accuracy: 0.7525
# Epoch 125/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5102 - accuracy: 0.7438
# Epoch 126/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5555 - accuracy: 0.7250
# Epoch 127/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4994 - accuracy: 0.7612
# Epoch 128/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4835 - accuracy: 0.7685
# Epoch 129/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5004 - accuracy: 0.7554
# Epoch 130/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4781 - accuracy: 0.7713
# Epoch 131/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4782 - accuracy: 0.7844
# Epoch 132/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4934 - accuracy: 0.7685
# Epoch 133/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 0.7728
# Epoch 134/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4716 - accuracy: 0.7873
# Epoch 135/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4820 - accuracy: 0.7685
# Epoch 136/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4726 - accuracy: 0.7786
# Epoch 137/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4838 - accuracy: 0.7612
# Epoch 138/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5021 - accuracy: 0.7554
# Epoch 139/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.5009 - accuracy: 0.7496
# Epoch 140/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4784 - accuracy: 0.7656
# Epoch 141/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4887 - accuracy: 0.7598
# Epoch 142/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4908 - accuracy: 0.7453
# Epoch 143/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4944 - accuracy: 0.7525
# Epoch 144/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4784 - accuracy: 0.7670
# Epoch 145/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4787 - accuracy: 0.7728
# Epoch 146/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4764 - accuracy: 0.7757
# Epoch 147/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4737 - accuracy: 0.7713
# Epoch 148/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4747 - accuracy: 0.7713
# Epoch 149/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4858 - accuracy: 0.7641
# Epoch 150/150
# 70/70 [==============================] - 0s 1ms/step - loss: 0.4937 - accuracy: 0.7627

# %% [markdown]
# ####  Evaluate Keras Model
# We have trained our neural network on the training dataset and we can evaluate the performance of the network on the test dataset. Let's first use the model to predict the actual classes for the test set
#
# Making predictions is as easy as calling the predict() function on the model. We are using a sigmoid activation function on the output layer, so the predictions will be a probability in the range between 0 and 1. We can easily convert them into a crisp binary prediction for this classification task by rounding them.
#
# ou can visualise your predictions using any of the sklearn capabilities. Example below shows the classification report.
#
# For example:

# %%
# make probability predictions with the model
predictions = model.predict(x_test)
# round predictions 
rounded = [round(x[0]) for x in predictions]
print(classification_report(y_test, rounded))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.92      0.80        48
#          1.0       0.73      0.38      0.50        29
#
#     accuracy                           0.71        77
#    macro avg       0.72      0.65      0.65        77
# weighted avg       0.72      0.71      0.69        77

# %% [markdown]
# <h2 id="keras_tuned">Changing the Model's Hyperparameters</h2>
#
#  - The NN above shows a very bad performance with respect to the positive class.
#  - Can we do better? let's try differnt parameters:
#      - batch_size
#      - epochs
#      - metrics (try: metrics=tf.keras.metrics.Precision())

# %%
### Your solution here ###

def create_model(neuron1, neuron2):
    model = Sequential()
    model.add(Dense(neuron1, input_dim=8, activation='relu'))
    model.add(Dense(neuron2, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
param_grid = {
    'neuron1': [10, 20],
    'neuron2': [10, 20],
    'batch_size': [5,10],
}

# %%
model = KerasClassifier(create_model)
validate = GridSearchCV(estimator=model, param_grid=param_grid, verbose=10)
validate_fit = validate.fit(x_train, y_train)
validate_fit.best_params_
# Out:
# /tmp/ipykernel_85566/1678935534.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(create_model)
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5; 1/8] START batch_size=5, neuron1=10, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 1.8255 - accuracy: 0.4348
# 28/28 [==============================] - 0s 1ms/step - loss: 1.1469 - accuracy: 0.4676
# [CV 1/5; 1/8] END batch_size=5, neuron1=10, neuron2=10;, score=0.468 total time=   0.6s
# [CV 2/5; 1/8] START batch_size=5, neuron1=10, neuron2=10........................
# 111/111 [==============================] - 0s 2ms/step - loss: 5.1434 - accuracy: 0.6474
# 28/28 [==============================] - 0s 1ms/step - loss: 2.8056 - accuracy: 0.5725
# [CV 2/5; 1/8] END batch_size=5, neuron1=10, neuron2=10;, score=0.572 total time=   0.7s
# [CV 3/5; 1/8] START batch_size=5, neuron1=10, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 0.9651 - accuracy: 0.6094
# 28/28 [==============================] - 0s 1ms/step - loss: 0.7844 - accuracy: 0.6014
# [CV 3/5; 1/8] END batch_size=5, neuron1=10, neuron2=10;, score=0.601 total time=   0.6s
# [CV 4/5; 1/8] START batch_size=5, neuron1=10, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 16.3360 - accuracy: 0.3508
# 28/28 [==============================] - 0s 1ms/step - loss: 3.8123 - accuracy: 0.3986
# [CV 4/5; 1/8] END batch_size=5, neuron1=10, neuron2=10;, score=0.399 total time=   0.6s
# [CV 5/5; 1/8] START batch_size=5, neuron1=10, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 4.7902 - accuracy: 0.4557
# 28/28 [==============================] - 0s 1ms/step - loss: 1.2338 - accuracy: 0.5507
# [CV 5/5; 1/8] END batch_size=5, neuron1=10, neuron2=10;, score=0.551 total time=   0.6s
# [CV 1/5; 2/8] START batch_size=5, neuron1=10, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 2.4432 - accuracy: 0.5924
# 28/28 [==============================] - 0s 1ms/step - loss: 0.7531 - accuracy: 0.6475
# [CV 1/5; 2/8] END batch_size=5, neuron1=10, neuron2=20;, score=0.647 total time=   0.7s
# [CV 2/5; 2/8] START batch_size=5, neuron1=10, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 1.6823 - accuracy: 0.5588
# 28/28 [==============================] - 0s 1ms/step - loss: 1.2723 - accuracy: 0.5870
# [CV 2/5; 2/8] END batch_size=5, neuron1=10, neuron2=20;, score=0.587 total time=   0.6s
# [CV 3/5; 2/8] START batch_size=5, neuron1=10, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 5.9318 - accuracy: 0.4177
# 28/28 [==============================] - 0s 1ms/step - loss: 1.0337 - accuracy: 0.5870
# [CV 3/5; 2/8] END batch_size=5, neuron1=10, neuron2=20;, score=0.587 total time=   0.6s
# [CV 4/5; 2/8] START batch_size=5, neuron1=10, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 6.2756 - accuracy: 0.5805
# 28/28 [==============================] - 0s 1ms/step - loss: 2.3931 - accuracy: 0.5145
# [CV 4/5; 2/8] END batch_size=5, neuron1=10, neuron2=20;, score=0.514 total time=   0.6s
# [CV 5/5; 2/8] START batch_size=5, neuron1=10, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 4.6794 - accuracy: 0.5895
# 28/28 [==============================] - 0s 1ms/step - loss: 2.1503 - accuracy: 0.5435
# [CV 5/5; 2/8] END batch_size=5, neuron1=10, neuron2=20;, score=0.543 total time=   0.6s
# [CV 1/5; 3/8] START batch_size=5, neuron1=20, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 3.8508 - accuracy: 0.3822
# 28/28 [==============================] - 1s 1ms/step - loss: 1.6062 - accuracy: 0.6259
# [CV 1/5; 3/8] END batch_size=5, neuron1=20, neuron2=10;, score=0.626 total time=   1.3s
# [CV 2/5; 3/8] START batch_size=5, neuron1=20, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 5.2441 - accuracy: 0.5497
# 28/28 [==============================] - 0s 1ms/step - loss: 2.3148 - accuracy: 0.5870
# [CV 2/5; 3/8] END batch_size=5, neuron1=20, neuron2=10;, score=0.587 total time=   0.7s
# [CV 3/5; 3/8] START batch_size=5, neuron1=20, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 4.1208 - accuracy: 0.6203
# 28/28 [==============================] - 0s 1ms/step - loss: 1.8544 - accuracy: 0.6087
# [CV 3/5; 3/8] END batch_size=5, neuron1=20, neuron2=10;, score=0.609 total time=   0.7s
# [CV 4/5; 3/8] START batch_size=5, neuron1=20, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 2.0451 - accuracy: 0.5678
# 28/28 [==============================] - 0s 1ms/step - loss: 1.1893 - accuracy: 0.6377
# [CV 4/5; 3/8] END batch_size=5, neuron1=20, neuron2=10;, score=0.638 total time=   0.7s
# [CV 5/5; 3/8] START batch_size=5, neuron1=20, neuron2=10........................
# 111/111 [==============================] - 0s 1ms/step - loss: 6.9903 - accuracy: 0.5732
# 28/28 [==============================] - 0s 1ms/step - loss: 1.8044 - accuracy: 0.6232
# [CV 5/5; 3/8] END batch_size=5, neuron1=20, neuron2=10;, score=0.623 total time=   0.7s
# [CV 1/5; 4/8] START batch_size=5, neuron1=20, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 2.2813 - accuracy: 0.5851
# 28/28 [==============================] - 0s 1ms/step - loss: 1.7493 - accuracy: 0.5683
# [CV 1/5; 4/8] END batch_size=5, neuron1=20, neuron2=20;, score=0.568 total time=   0.6s
# [CV 2/5; 4/8] START batch_size=5, neuron1=20, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 2.2891 - accuracy: 0.6184
# 28/28 [==============================] - 0s 1ms/step - loss: 1.3044 - accuracy: 0.6232
# [CV 2/5; 4/8] END batch_size=5, neuron1=20, neuron2=20;, score=0.623 total time=   0.6s
# [CV 3/5; 4/8] START batch_size=5, neuron1=20, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 2.1336 - accuracy: 0.5497
# 28/28 [==============================] - 0s 1ms/step - loss: 1.3328 - accuracy: 0.6304
# [CV 3/5; 4/8] END batch_size=5, neuron1=20, neuron2=20;, score=0.630 total time=   0.6s
# [CV 4/5; 4/8] START batch_size=5, neuron1=20, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 12.8823 - accuracy: 0.6564
# 28/28 [==============================] - 0s 1ms/step - loss: 2.6533 - accuracy: 0.5362
# [CV 4/5; 4/8] END batch_size=5, neuron1=20, neuron2=20;, score=0.536 total time=   0.6s
# [CV 5/5; 4/8] START batch_size=5, neuron1=20, neuron2=20........................
# 111/111 [==============================] - 0s 1ms/step - loss: 1.1737 - accuracy: 0.5280
# 28/28 [==============================] - 0s 1ms/step - loss: 0.7746 - accuracy: 0.6667
# [CV 5/5; 4/8] END batch_size=5, neuron1=20, neuron2=20;, score=0.667 total time=   0.6s
# [CV 1/5; 5/8] START batch_size=10, neuron1=10, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 11.7964 - accuracy: 0.3569
# 14/14 [==============================] - 0s 1ms/step - loss: 7.3312 - accuracy: 0.2950
# [CV 1/5; 5/8] END batch_size=10, neuron1=10, neuron2=10;, score=0.295 total time=   0.5s
# [CV 2/5; 5/8] START batch_size=10, neuron1=10, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 3.9395 - accuracy: 0.6329
# 14/14 [==============================] - 0s 1ms/step - loss: 2.8475 - accuracy: 0.4928
# [CV 2/5; 5/8] END batch_size=10, neuron1=10, neuron2=10;, score=0.493 total time=   0.6s
# [CV 3/5; 5/8] START batch_size=10, neuron1=10, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 5.3745 - accuracy: 0.6130
# 14/14 [==============================] - 0s 1ms/step - loss: 3.3121 - accuracy: 0.6377
# [CV 3/5; 5/8] END batch_size=10, neuron1=10, neuron2=10;, score=0.638 total time=   0.6s
# [CV 4/5; 5/8] START batch_size=10, neuron1=10, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 2.8711 - accuracy: 0.5660
# 14/14 [==============================] - 0s 1ms/step - loss: 2.4047 - accuracy: 0.5290
# [CV 4/5; 5/8] END batch_size=10, neuron1=10, neuron2=10;, score=0.529 total time=   0.6s
# [CV 5/5; 5/8] START batch_size=10, neuron1=10, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 2.7918 - accuracy: 0.5099
# 14/14 [==============================] - 0s 1ms/step - loss: 1.7149 - accuracy: 0.5507
# [CV 5/5; 5/8] END batch_size=10, neuron1=10, neuron2=10;, score=0.551 total time=   0.6s
# [CV 1/5; 6/8] START batch_size=10, neuron1=10, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 2.9564 - accuracy: 0.5145
# 14/14 [==============================] - 0s 1ms/step - loss: 1.4984 - accuracy: 0.5755
# [CV 1/5; 6/8] END batch_size=10, neuron1=10, neuron2=20;, score=0.576 total time=   0.5s
# [CV 2/5; 6/8] START batch_size=10, neuron1=10, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 2.3088 - accuracy: 0.6112
# 14/14 [==============================] - 0s 1ms/step - loss: 1.9930 - accuracy: 0.5290
# [CV 2/5; 6/8] END batch_size=10, neuron1=10, neuron2=20;, score=0.529 total time=   0.5s
# [CV 3/5; 6/8] START batch_size=10, neuron1=10, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 14.3311 - accuracy: 0.4575
# 14/14 [==============================] - 0s 1ms/step - loss: 4.0449 - accuracy: 0.5942
# [CV 3/5; 6/8] END batch_size=10, neuron1=10, neuron2=20;, score=0.594 total time=   0.5s
# [CV 4/5; 6/8] START batch_size=10, neuron1=10, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 5.3117 - accuracy: 0.3490
# 14/14 [==============================] - 0s 1ms/step - loss: 1.8097 - accuracy: 0.3406
# [CV 4/5; 6/8] END batch_size=10, neuron1=10, neuron2=20;, score=0.341 total time=   0.5s
# [CV 5/5; 6/8] START batch_size=10, neuron1=10, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 1.0600 - accuracy: 0.5552
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7345 - accuracy: 0.6594
# [CV 5/5; 6/8] END batch_size=10, neuron1=10, neuron2=20;, score=0.659 total time=   0.5s
# [CV 1/5; 7/8] START batch_size=10, neuron1=20, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 8.4757 - accuracy: 0.5743
# 14/14 [==============================] - 0s 1ms/step - loss: 2.6112 - accuracy: 0.4964
# [CV 1/5; 7/8] END batch_size=10, neuron1=20, neuron2=10;, score=0.496 total time=   0.6s
# [CV 2/5; 7/8] START batch_size=10, neuron1=20, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 6.4321 - accuracy: 0.4322
# 14/14 [==============================] - 0s 1ms/step - loss: 2.7956 - accuracy: 0.3913
# [CV 2/5; 7/8] END batch_size=10, neuron1=20, neuron2=10;, score=0.391 total time=   0.5s
# [CV 3/5; 7/8] START batch_size=10, neuron1=20, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 1.6380 - accuracy: 0.5769
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7870 - accuracy: 0.6232
# [CV 3/5; 7/8] END batch_size=10, neuron1=20, neuron2=10;, score=0.623 total time=   0.6s
# [CV 4/5; 7/8] START batch_size=10, neuron1=20, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 2.5637 - accuracy: 0.5787
# 14/14 [==============================] - 0s 1ms/step - loss: 2.6045 - accuracy: 0.6304
# [CV 4/5; 7/8] END batch_size=10, neuron1=20, neuron2=10;, score=0.630 total time=   0.7s
# [CV 5/5; 7/8] START batch_size=10, neuron1=20, neuron2=10.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 9.0571 - accuracy: 0.4792
# 14/14 [==============================] - 0s 1ms/step - loss: 3.2862 - accuracy: 0.5145
# [CV 5/5; 7/8] END batch_size=10, neuron1=20, neuron2=10;, score=0.514 total time=   0.6s
# [CV 1/5; 8/8] START batch_size=10, neuron1=20, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 3.1528 - accuracy: 0.5326
# 14/14 [==============================] - 0s 1ms/step - loss: 1.6222 - accuracy: 0.5252
# [CV 1/5; 8/8] END batch_size=10, neuron1=20, neuron2=20;, score=0.525 total time=   0.5s
# [CV 2/5; 8/8] START batch_size=10, neuron1=20, neuron2=20.......................
# 56/56 [==============================] - 1s 1ms/step - loss: 2.3178 - accuracy: 0.5208
# 14/14 [==============================] - 0s 1ms/step - loss: 1.0507 - accuracy: 0.5725
# [CV 2/5; 8/8] END batch_size=10, neuron1=20, neuron2=20;, score=0.572 total time=   1.3s
# [CV 3/5; 8/8] START batch_size=10, neuron1=20, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 1.6694 - accuracy: 0.5606
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7797 - accuracy: 0.6449
# [CV 3/5; 8/8] END batch_size=10, neuron1=20, neuron2=20;, score=0.645 total time=   0.6s
# [CV 4/5; 8/8] START batch_size=10, neuron1=20, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 4.1231 - accuracy: 0.5696
# 14/14 [==============================] - 0s 1ms/step - loss: 1.9233 - accuracy: 0.5145
# [CV 4/5; 8/8] END batch_size=10, neuron1=20, neuron2=20;, score=0.514 total time=   0.6s
# [CV 5/5; 8/8] START batch_size=10, neuron1=20, neuron2=20.......................
# 56/56 [==============================] - 0s 1ms/step - loss: 1.5252 - accuracy: 0.5877
# 14/14 [==============================] - 0s 1ms/step - loss: 0.9372 - accuracy: 0.5072
# [CV 5/5; 8/8] END batch_size=10, neuron1=20, neuron2=20;, score=0.507 total time=   0.6s
# 139/139 [==============================] - 0s 1ms/step - loss: 3.4422 - accuracy: 0.5485
# {'batch_size': 5, 'neuron1': 20, 'neuron2': 10}

# %%
## the model still performs badly, especially w.r.t. the positive class. There's a big class imbalance, see here: 
import numpy as np

values, counts = np.unique(y, return_counts=True)
print(counts)
##there is double the number of samples in the negative class. 
## NNs are very data hungry. they would require much more data about the positive class to make good predictions!
## We will learn how to deal with class imbalance next week! :)
# Out:
# [500 268]
